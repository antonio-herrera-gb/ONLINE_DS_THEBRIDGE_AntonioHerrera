# %%
import pandas as pd

# %%
df = pd.read_csv('./data/adidas_sales.csv')
df
# Out:
#            Retailer  Retailer ID Invoice Date     Region        State  \
# 0           Walmart      1128299    6/17/2021  Southeast      Florida
# 1         West Gear      1128299    7/16/2021      South    Louisiana
# 2     Sports Direct      1197831    8/25/2021      South      Alabama
# 3     Sports Direct      1197831    8/27/2021      South      Alabama
# 4     Sports Direct      1197831    8/21/2021      South      Alabama
# ...             ...          ...          ...        ...          ...
# 9636         Amazon      1185732   11/18/2021  Northeast        Maine
# 9637         Amazon      1185732   10/22/2021       West       Alaska
# 9638         Amazon      1185732   10/22/2021       West       Alaska
# 9639      West Gear      1185732    4/10/2021    Midwest      Indiana
# 9640  Sports Direct      1185732    10/5/2021  Northeast  Connecticut
#
#               City                    Product Price per Unit Units Sold  \
# ...

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
df
# Out:
#            retailer  retailer_id invoice_date     region        state  \
# 0           Walmart      1128299    6/17/2021  Southeast      Florida
# 1         West Gear      1128299    7/16/2021      South    Louisiana
# 2     Sports Direct      1197831    8/25/2021      South      Alabama
# 3     Sports Direct      1197831    8/27/2021      South      Alabama
# 4     Sports Direct      1197831    8/21/2021      South      Alabama
# ...             ...          ...          ...        ...          ...
# 9636         Amazon      1185732   11/18/2021  Northeast        Maine
# 9637         Amazon      1185732   10/22/2021       West       Alaska
# 9638         Amazon      1185732   10/22/2021       West       Alaska
# 9639      West Gear      1185732    4/10/2021    Midwest      Indiana
# 9640  Sports Direct      1185732    10/5/2021  Northeast  Connecticut
#
#               city                    product price_per_unit units_sold  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9641 entries, 0 to 9640
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9641 non-null   object
#  1   retailer_id       9641 non-null   int64
#  2   invoice_date      9641 non-null   object
#  3   region            9641 non-null   object
#  4   state             9641 non-null   object
#  5   city              9641 non-null   object
#  6   product           9641 non-null   object
#  7   price_per_unit    9639 non-null   object
#  8   units_sold        9641 non-null   object
#  9   total_sales       9641 non-null   object
#  10  operating_profit  9641 non-null   object
#  11  sales_method      9641 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 904.0+ KB

# %%
df["invoice_date"] = pd.to_datetime(df["invoice_date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9641 entries, 0 to 9640
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9641 non-null   object
#  1   retailer_id       9641 non-null   int64
#  2   invoice_date      9641 non-null   datetime64[ns]
#  3   region            9641 non-null   object
#  4   state             9641 non-null   object
#  5   city              9641 non-null   object
#  6   product           9641 non-null   object
#  7   price_per_unit    9639 non-null   object
#  8   units_sold        9641 non-null   object
#  9   total_sales       9641 non-null   object
#  10  operating_profit  9641 non-null   object
#  11  sales_method      9641 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 904.0+ KB

# %%
df = df.sort_values(by="invoice_date")

# %%
df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 4908  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 30    Foot Locker      1185732   2020-01-01  Northeast      New York
# 4937  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 9189  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 79    Foot Locker      1185732   2020-01-01  Northeast      New York
# ...           ...          ...          ...        ...           ...
# 9605  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 6312       Amazon      1185732   2021-12-31  Northeast         Maine
# 6041  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 5826  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 3413       Amazon      1185732   2021-12-31  Northeast         Maine
#
#               city                product price_per_unit units_sold  \
# 4908  Philadelphia        Women's Apparel        $68.00          83
# ...

# %%
df = df.dropna()
df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 4908  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 30    Foot Locker      1185732   2020-01-01  Northeast      New York
# 4937  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 9189  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 79    Foot Locker      1185732   2020-01-01  Northeast      New York
# ...           ...          ...          ...        ...           ...
# 9605  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 6312       Amazon      1185732   2021-12-31  Northeast         Maine
# 6041  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 5826  Foot Locker      1185732   2021-12-31  Northeast  Pennsylvania
# 3413       Amazon      1185732   2021-12-31  Northeast         Maine
#
#               city                product price_per_unit units_sold  \
# 4908  Philadelphia        Women's Apparel        $68.00          83
# ...

# %%
df = df.drop(columns=["retailer_id", "operating_profit", "sales_method"])

# %%
# le falta un cero de mas a la columna de total_sales
# quitar el dolar

# %%
df
# Out:
#          retailer invoice_date     region         state          city  \
# 4908  Foot Locker   2020-01-01  Northeast  Pennsylvania  Philadelphia
# 30    Foot Locker   2020-01-01  Northeast      New York      New York
# 4937  Foot Locker   2020-01-01  Northeast  Pennsylvania  Philadelphia
# 9189  Foot Locker   2020-01-01  Northeast  Pennsylvania  Philadelphia
# 79    Foot Locker   2020-01-01  Northeast      New York      New York
# ...           ...          ...        ...           ...           ...
# 9605  Foot Locker   2021-12-31  Northeast  Pennsylvania  Philadelphia
# 6312       Amazon   2021-12-31  Northeast         Maine      Portland
# 6041  Foot Locker   2021-12-31  Northeast  Pennsylvania  Philadelphia
# 5826  Foot Locker   2021-12-31  Northeast  Pennsylvania  Philadelphia
# 3413       Amazon   2021-12-31  Northeast         Maine      Portland
#
#                     product price_per_unit units_sold total_sales
# ...
